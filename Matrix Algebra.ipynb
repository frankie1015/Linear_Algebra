# %% [markdown]
# FRANCINE YSABELLE BORROMEO

# %% [markdown]
# Without the use of any python libraries or modules, develop a function that can perform matrix addition, given two numpy matrices.

# %%
def matrix_addition(matrix1, matrix2):
    if len(matrix1) != len(matrix2) or len(matrix1[0]) != len(matrix2[0]):
        raise ValueError("Matrices must have the same dimensions for addition.")
    result_matrix = [[0] * len(matrix1[0]) for _ in range(len(matrix1))]

    for i in range(len(matrix1)):
        for j in range(len(matrix1[0])):
            result_matrix[i][j] = matrix1[i][j] + matrix2[i][j]

    return result_matrix
matrix_a = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

matrix_b = [
    [9, 8, 7],
    [6, 5, 4],
    [3, 2, 1]
]

result = matrix_addition(matrix_a, matrix_b)
for row in result:
    print(row)
# Out:
# [10, 10, 10]
# [10, 10, 10]
# [10, 10, 10]

# %% [markdown]
# Without the use of any python libraries or modules, develop a function that can multiply two numpy matrices.

# %%
def matrix_multiplication(matrix1, matrix2):
    if len(matrix1[0]) != len(matrix2):
        raise ValueError("Number of columns in the first matrix must be equal to the number of rows in the second matrix.")
    result_matrix = [[0] * len(matrix2[0]) for _ in range(len(matrix1))]

    for i in range(len(matrix1)):
        for j in range(len(matrix2[0])):
            for k in range(len(matrix2)):
                result_matrix[i][j] += matrix1[i][k] * matrix2[k][j]

    return result_matrix
matrix_a = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

matrix_b = [
    [9, 8, 7],
    [6, 5, 4],
    [3, 2, 1]
]

result = matrix_multiplication(matrix_a, matrix_b)
for row in result:
    print(row)
# Out:
# [30, 24, 18]
# [84, 69, 54]
# [138, 114, 90]

# %% [markdown]
# The rule of distributivity states that given two matrices 𝐴 and 𝐵 and a scalar, 𝑘, then 𝑘(𝐴+𝐵)=𝑘𝐴+𝑘𝐵. Instead of writing a proof mathematically, develop two codes for 𝑘(𝐴+𝐵) and 𝑘𝐴+𝑘𝐵.

# %%
def scalar_matrix_addition(scalar, matrix1, matrix2):
    if len(matrix1) != len(matrix2) or len(matrix1[0]) != len(matrix2[0]):
        raise ValueError("Matrices must have the same dimensions for addition.")
    result_matrix = [[0] * len(matrix1[0]) for _ in range(len(matrix1))]

    for i in range(len(matrix1)):
        for j in range(len(matrix1[0])):
            result_matrix[i][j] = scalar * (matrix1[i][j] + matrix2[i][j])

    return result_matrix


def scalar_matrix_multiplication(scalar, matrix):
    result_matrix = [[0] * len(matrix[0]) for _ in range(len(matrix))]
    for i in range(len(matrix)):
        for j in range(len(matrix[0])):
            result_matrix[i][j] = scalar * matrix[i][j]

    return result_matrix
scalar = 2
matrix_a = [
    [1, 2],
    [3, 4]
]

matrix_b = [
    [5, 6],
    [7, 8]
]

# k(A + B)
result_addition = scalar_matrix_addition(scalar, matrix_a, matrix_b)

# kA + kB
result_multiplication = scalar_matrix_addition(scalar, matrix_a, matrix_b)

# Print results
print("k(A + B):")
for row in result_addition:
    print(row)

print("\nkA + kB:")
for row in result_multiplication:
    print(row)
# Out:
# k(A + B):
# [12, 16]
# [20, 24]
#
# kA + kB:
# [12, 16]
# [20, 24]

# %% [markdown]
# Without using a python library or modules develop a function that can extract the diagonal of a numpy matrix.

# %%
def extract_diagonal(matrix):
    if len(matrix) != len(matrix[0]):
        raise ValueError("Matrix must be square to extract the diagonal.")

    diagonal = [matrix[i][i] for i in range(len(matrix))]

    return diagonal

matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

result = extract_diagonal(matrix)
print("Diagonal elements:", result)
# Out:
# Diagonal elements: [1, 5, 9]

# %% [markdown]
# Without using a python library or modules develop a function that can find a trace of a numpy matrix.

# %%
def matrix_trace(matrix):
    if len(matrix) != len(matrix[0]):
        raise ValueError("Matrix must be square to find the trace.")
    trace_sum = sum(matrix[i][i] for i in range(len(matrix)))

    return trace_sum

matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

result = matrix_trace(matrix)
print("Trace of the matrix:", result)
# Out:
# Trace of the matrix: 15

# %% [markdown]
# Problem Solving
# 1. Solve $X$ given that:
#  \begin{equation}\
#      A =
#  \\begin{bmatrix}\
#     1 & 2 \\\\\
#     3 & 4 \\\\\
#   \\end{bmatrix}
#
# \\begin{equation}\
#      B =
#  \\begin{bmatrix}\
#     -1 & 0 \\\\\
#      1 & 1 \\\\\
#   \\end{bmatrix}
#
#   $3X = A - 2B \\\\ X = \\frac{1}{3}(A - 2B)\\\\$ <br>
#   A - 2B =
#    \\begin{bmatrix}\
#     1 & 2 \\\\\
#     3 & 4 \\\\\
#     \\end{bmatrix} -  2 \\begin{bmatrix}\
#     -1 & 0 \\\\\
#      1 & 1 \\\\\
#   \\end{bmatrix}
#   \\begin{bmatrix}\
#     3 & 2 \\\\\
#     1 & 2 \\\\\
#     \\end{bmatrix}
#
#   X =
#   \\begin{equation}\
#   \\begin{bmatrix}\
#     1 & \\frac{2}{3} \\\\\
#     \\frac{1}{3} & \\frac{2}{3} \\\\\
#    \\end{bmatrix}

# %%
import numpy as np

A = np.array([[1, 2], [3, 4]])
B = np.array([[-1, 0], [1, 1]])

result = A - (2 * B)
X = result / 3
print("X = ")
print(X)
# Out:
# X =
# [[1.         0.66666667]
#  [0.33333333 0.66666667]]

# %% [markdown]
#  $2(A-B+2X) = 3(X-B)$ <br>
#  $2A - 2B + 4X = 3X - 3B$ <br>
#  $4X - 3X = 2B - 2A - 3B$ <br>
#  $X = (2B - 2A - 3B)$ <br>
#  $X = 2$
#  \begin{equation}\
#  \\begin{bmatrix}\
#   -1 & 0 \\\\\
#   1 & 1 \\\\\
#   \\end{bmatrix}\ - 2
#   \\begin{bmatrix}\
#   1 & 2 \\\\\
#   3 & 4 \\\\\
#   \\end{bmatrix} - 3
#   \\begin{bmatrix}\
#   -1 & 0 \\\\\
#   1 & 1 \\\\\
#   \\end{bmatrix}\ =
#   \\begin{bmatrix}\
#   -2 & 0 \\\\\
#   2 & 2 \\\\\
#   \\end{bmatrix}\
#   \\begin{bmatrix}\
#   2 & 4 \\\\\
#   6 & 8 \\\\\
#   \\end{bmatrix}\
#   \\begin{bmatrix}\
#   -3 & 0 \\\\\
#   3 & 3 \\\\\
#   \\end{bmatrix}\ =
#   \\begin{bmatrix}\
#   -2-2+3 & 0-4-4 \\\\\
#   2--3 & 2-8-3 \\\\\
#   \\end{bmatrix}\ =
#   \\begin{bmatrix}\
#   -1 & -4 \\\\\
#   -7 & -9 \\\\\
#   \\end{bmatrix}\

# %%
import numpy as np
A = np.array([[1, 2], [3, 4]])
B = np.array([[-1, 0], [1, 1]])
X = (2 * B) - (2 * A) - (3 * B)
print("X =")
print(X)
# Out:
# X =
# [[-1 -4]
#  [-7 -9]]

# %% [markdown]
# 2. Write $B$ as a linear combination of the other matrices, if possible.
# \\begin{equation}\
# $A_1$ =
# \\begin{bmatrix}\
# 1 & 2 \\\\\
# -1 & 1 \\\\\
# \\end{bmatrix}
# $A_2$ =
# \\begin{bmatrix}\
# 0 & 1 \\\\\
# 2 & 1 \\\\\
# \\end{bmatrix}
# B =
# \\begin{bmatrix}\
# 2 & 5 \\\\\
# 0 & 3 \\\\\
# \\end{bmatrix}
# $B = c_1A_1 + c_2A_2$ <br>
# $2 = c_1 \\cdot 1 + c_2 \\cdot 0$<br>
# $5 = c_1 \\cdot 2 + c_2 \\cdot 1$ <br>
# $0 = c_1 \\cdot (-1) + c_2 \\cdot 2$ <br>
# $3 = c_1 \\cdot 1 + c_2 \\cdot 1$<br>
# Equation1:  $2 = c_1 \\quad \\Rightarrow \\quad c_1 = 2$ <br>
# Equation2: $5 = 2c_1 + c_2 = 2 \\cdot 2 + c_2 \\quad \\Rightarrow \\quad c_2 = -4$ <br>
# $c_1 = 2$ <br>
# $c_2 = -4$ <br>
# $B = 2A_1 - 4A_2$
# $A_1$ =
# \\begin{bmatrix}\
# 1 & 0 \\\\\
# 0 & 1 \\\\\
# \\end{bmatrix}
# $A_2$ =
# \\begin{bmatrix}\
# 0 & 1 \\\\\
# 1 & 0 \\\\\
# \\end{bmatrix}
# $A_3$ =
# \\begin{bmatrix}\
# 1 & -1 \\\\\
# 1 & 1 \\\\\
# \\end{bmatrix}
# B =
# \\begin{bmatrix}\
# 2 & 5 \\\\\
# 0 & 3 \\\\\
# $B = c_1A_1 + c_2A_2 + c_3A_3$ <br>
# $2 = c_1 \\cdot 1 + c_2 \\cdot 0 + c_3 \\cdot 1$ <br>
# $5 = c_1 \\cdot 0 + c_2 \\cdot 1 + c_3 \\cdot (-1)$<br>
# $0 = c_1 \\cdot 1 + c_2 \\cdot 1 + c_3 \\cdot 1$<br>
# $3 = c_1 \\cdot 0 + c_2 \\cdot 0 + c_3 \\cdot 1$<br>
# $2 = c_1 + c_3$<br>
# $5 = c_2 - c_3$<br>
# $0 = c_1 + c_2 + c_3$<br>
# $3 = c_3$<br>
# $2 = c_1 + 3$<br>
# $c_1 = -1$<br>
# $5 = c_2 - 3$<br>
# $c_2 = 8$<br>
# $3 = c_3$ <br>
# $c_3 = 3$<br>
# $B = -1A_1 + 8A_2 + 3A_3$<br>

# %% [markdown]
# 3.
# \\begin{equation}\
# $A$ =
# \\begin{bmatrix}\
# 1 & 2 \\\\\
# 2 & 6 \\\\\
# \\end{bmatrix}
# $b_1$ =
# \\begin{bmatrix}\
# 3 \\\\\
# 5 \\\\\
# \\end{bmatrix}
# $b_2$ =
# \\begin{bmatrix}\
# -1\\\\\
# 2\\\\\
# \\end{bmatrix}
# $b_3$ =
# \\begin{bmatrix}\
# 2\\\\\
# 0\\\\\
# \\end{bmatrix}
# = <br>
# $A^{-1} = (\\frac{1}{det(A)}) $*
# \\begin{bmatrix}\
# d & -b \\\\\
# -c & a \\\\\
# \\end{bmatrix} <br>
# $det(A) = (1 * 6) - (2 * 2) = 6 - 4 = 2 $
# $A^{-1} = (\\frac{1}{2})$ *
# \\begin{bmatrix}\
# 6 & -2 \\\\\
# -2 & 1 \\\\\
# \\end{bmatrix} =
# \\begin{bmatrix}\
# 3 & -1 \\\\\
# -1 & \\frac{1}{2} \\\\\
# \\end{bmatrix}
# A | b_1 =
# \\begin{bmatrix}\\begin{array}{cc|c}\
# 1 & 2 & 3 \\\\\
# 2 & 6 & 5 \\\\\
# \\end{array}\\end{bmatrix}
# \\begin{bmatrix}\\begin{array}{cc|c}\
# 1 & 2 & 3 \\\\\
# 0 & 2 & -1 \\\\\
# \\end{array}\\end{bmatrix}
# \\begin{bmatrix}\\begin{array}{cc|c}\
# 1 & 2 & 3 \\\\\
# 0 & 1 & -0.5 \\\\\
# \\end{array}\\end{bmatrix}
# \\begin{bmatrix}\\begin{array}{cc|c}\
# 1 & 0 & 4 \\\\\
# 2 & 6 & 5 \\\\\
# \\end{array}\\end{bmatrix}
# A |$b_1$: <br>
# $x_1 = 4$ <br>
# $x_2 = -0.5$ <br>
# A |$b_2$: <br>
# \\begin{bmatrix}\\begin{array}{cc|c}\
# 1 & 2 & -1 \\\\\
# 2 & 6 & 2 \\\\\
# \\end{array}\\end{bmatrix}
# \\begin{bmatrix}\\begin{array}{cc|c}\
# 1 & 2 & -1 \\\\\
# 0 & 2 & 4 \\\\\
# \\end{array}\\end{bmatrix}
# \\begin{bmatrix}\\begin{array}{cc|c}\
# 1 & 2 & -1 \\\\\
# 0 & 1 & 2 \\\\\
# \\end{array}\\end{bmatrix}
# \\begin{bmatrix}\\begin{array}{cc|c}\
# 1 & 0 & -5 \\\\\
# 0 & 1 & 2 \\\\\
# \\end{array}\\end{bmatrix}
# A |$b_2$: <br>
# $x_1 = -5$ <br>
# $x_2 = 2$ <br>
# A |$b_3$: <br>
# \\begin{bmatrix}\\begin{array}{cc|c}\
# 1 & 2 & 2 \\\\\
# 2 & 6 & 0 \\\\\
# \\end{array}\\end{bmatrix}
# \\begin{bmatrix}\\begin{array}{cc|c}\
# 1 & 2 & 2 \\\\\
# 0 & 2 & -4 \\\\\
# \\end{array}\\end{bmatrix}
# \\begin{bmatrix}\\begin{array}{cc|c}\
# 1 & 2 & 2 \\\\\
# 0 & 1 & -2 \\\\\
# \\end{array}\\end{bmatrix}
# \\begin{bmatrix}\\begin{array}{cc|c}\
# 1 & 0 & 6 \\\\\
# 0 & 1 & -2 \\\\\
# \\end{array}\\end{bmatrix}
# A |$b_3$: <br>
# $x_1 = 6$ <br>
# $x_2 = -2$ <br>

# %% [markdown]
# 4.
# \\begin{equation}\
# $A$ =
# \\begin{bmatrix}\
# 1 & 0 & -1 \\\\\
# 1 & 1 & 1 \\\\\
# \\end{bmatrix}
# $b$ =
# \\begin{bmatrix}\
# 3\\\\\
# 2\\\\\
# \\end{bmatrix}
# $w$ =
# \\begin{bmatrix}\
# -1 &\
# 1 &\
# 1
# \\end{bmatrix}
# $A$ =
# \\begin{bmatrix}\
# 1 & 0 & -1 \\\\\
# 1 & 1 & 1 \\\\\
# \\end{bmatrix}
# \\begin{bmatrix}\
# 1 & 0 & -1 \\\\\
# 0 & 1 & 2 \\\\\
# \\end{bmatrix}
# $v_1 = [1, 1] , v_2 = [0,1]$<br>
# $c_1$\\begin{bmatrix} 1 \\\\ 1 \\end{bmatrix} + $c_2$ \\begin{bmatrix} 0 \\\\ 1 \\end{bmatrix} = \\begin{bmatrix} 3 \\\\ 2  \\end{bmatrix}
# $c_1 = 3$<br>
# $c_1 + c_2 = 2 \\Rightarrow c_2 = -1$ <br>
# rows space of A: $rv_1 = \\begin{bmatrix}\
# 1 &\
# 0 &\
# -1
# \\end{bmatrix}$ and $rv_2 = \\begin{bmatrix}\
# 1 &\
# 1 &\
# 1
# \\end{bmatrix} $<br>
# Vector w = \\begin{bmatrix}\
# -1 &\
# 1 &\
# 1
# \\end{bmatrix} $d_1$\\begin{bmatrix}\
# 1 &\
# 0 &\
# -1
# \\end{bmatrix} + $d_2$ \\begin{bmatrix}\
# 1 &\
# 1 &\
# 1
# \\end{bmatrix} = \\begin{bmatrix}\
# -1 &\
# 1 &\
# 1
# \\end{bmatrix}
# vector b is in the column space of A
# vector w is in the row space of A

# %% [markdown]
# 5.
# \\begin{equation}\
# \\begin{bmatrix}\
# 2 & 4 & 0 & 0 & 1 \\\\\
# 6 & 3 & 5 & 1 & 0 \\\\\
# 1 & 0 & 2 & 2 & 5 \\\\\
# 1 & 1 & 1 & 1 & 1 \\\\\
# \\end{bmatrix}
#
# \\begin{equation}\
# \\begin{bmatrix}\
# 2 & 4 & 0 & 0 & 1 \\\\\
# 0 & -9 & 5 & 1 & -3 \\\\\
# 1 & 0 & 2 & 2 & 5 \\\\\
# 1 & 1 & 1 & 1 & 1 \\\\\
# \\end{bmatrix}
#
# \\begin{equation}\
# \\begin{bmatrix}\
# 2 & 4 & 0 & 0 & 1 \\\\\
# 0 & -9 & 5 & 1 & -3 \\\\\
# 0 & -2 & 2 & 2 & 4 \\\\\
# 1 & 1 & 1 & 1 & 1 \\\\\
# \\end{bmatrix}
#
# \\begin{equation}\
# \\begin{bmatrix}\
# 2 & 4 & 0 & 0 & 1 \\\\\
# 0 & -9 & 5 & 1 & -3 \\\\\
# 0 & -2 & 2 & 2 & 4 \\\\\
# 0 & -1 & 1 & 1 & 0.5 \\\\\
# \\end{bmatrix}
#
# \\begin{equation}\
# \\begin{bmatrix}\
# 2 & 4 & 0 & 0 & 1 \\\\\
# 0 & 1 & -\\frac{5}{9} & -\\frac{1}{9} & \\frac{1}{3} \\\\\
# 0 & -2 & 2 & 2 & 4 \\\\\
# 0 & -1 & 1 & 1 & 0.5 \\\\\
# \\end{bmatrix}
#
# \\begin{equation}\
# \\begin{bmatrix}\
# 2 & 4 & 0 & 0 & 1 \\\\\
# 0 & 1 & -\\frac{5}{9} & -\\frac{1}{9} & \\frac{1}{3} \\\\\
# 0 & 0 & \\frac{8}{9} &\\frac{4}{9} & \\frac{10}{3} \\\\\
# 0 & -1 & 1 & 1 & 0.5 \\\\\
# \\end{bmatrix}
#
# \\begin{equation}\
# \\begin{bmatrix}\
# 2 & 4 & 0 & 0 & 1 \\\\\
# 0 & 1 & -\\frac{5}{9} & -\\frac{1}{9} & \\frac{1}{3} \\\\\
# 0 & 0 & \\frac{8}{9} &\\frac{4}{9} & \\frac{10}{3} \\\\\
# 0 & 0 & \\frac{1}{9} & \\frac{10}{9} & \\frac{2}{3}\\\\\
# \\end{bmatrix}
#
# \\begin{equation}\
# \\begin{bmatrix}\
# 2 & 4 & 0 & 0 & 1 \\\\\
# 0 & 1 & -\\frac{5}{9} & -\\frac{1}{9} & \\frac{1}{3} \\\\\
# 0 & 0 & 1 &\\frac{1}{2} & \\frac{15}{4} \\\\\
# 0 & 0 & \\frac{1}{9} & \\frac{10}{9} & \\frac{2}{3}\\\\\
# \\end{bmatrix}
